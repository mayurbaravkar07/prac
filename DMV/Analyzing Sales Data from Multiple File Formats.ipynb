# %% [markdown]
# ### Name : Kumbhar Gaurav
# ### Roll No : 34

# %% [markdown]
# <hr><b>

# %% [markdown]
# ### Data Loading, Storage and File Formats

# %%
import pandas as pd
import numpy as np

# %%
csv_data = pd.read_csv('sales_data.csv', encoding=('ISO-8859-1'),index_col=0)  # Replace 'sales_data.csv' with your CSV file name
excel_data = pd.read_excel('sales_data.xlsx')  # Replace 'sales_data.xlsx' with your Excel file name
json_data = pd.read_json('sales_data.json')

# %%
print("CSV Data:")
print(csv_data.head())
print("\nExcel Data:")
print(excel_data.head())
print("\nJSON Data:")
print(json_data.head())
# Out:
# CSV Data:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERNUMBER
# 10107                     30      95.70                2  2871.00
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
#
#                    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  \
# ORDERNUMBER
# 10107         2/24/2003 0:00  Shipped       1         2     2003  Motorcycles
# 10121          5/7/2003 0:00  Shipped       2         5     2003  Motorcycles
# 10134          7/1/2003 0:00  Shipped       3         7     2003  Motorcycles
# 10145         8/25/2003 0:00  Shipped       3         8     2003  Motorcycles
# 10159        10/10/2003 0:00  Shipped       4        10     2003  Motorcycles
#
# ...

# %%
csv_data
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERNUMBER
# 10107                     30      95.70                2  2871.00
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
# ...                      ...        ...              ...      ...
# 10350                     20     100.00               15  2244.40
# 10373                     29     100.00                1  3978.51
# 10386                     43     100.00                4  5417.57
# 10397                     34      62.24                1  2116.16
# 10414                     47      65.52                9  3079.44
#
#                    ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# ORDERNUMBER
# 10107         2/24/2003 0:00   Shipped       1         2     2003
# ...

# %% [markdown]
# #  Explore the structure and content of the loaded data, identifying any inconsistencies, missing values, or data quality issues.

# %%
csv_data.describe()
# Out:
#        QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER         SALES  \
# count      2823.000000  2823.000000      2823.000000   2823.000000
# mean         35.092809    83.658544         6.466171   3553.889072
# std           9.741443    20.174277         4.225841   1841.865106
# min           6.000000    26.880000         1.000000    482.130000
# 25%          27.000000    68.860000         3.000000   2203.430000
# 50%          35.000000    95.700000         6.000000   3184.800000
# 75%          43.000000   100.000000         9.000000   4508.000000
# max          97.000000   100.000000        18.000000  14082.800000
#
#             QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count  2823.000000  2823.000000  2823.00000  2823.000000
# mean      2.717676     7.092455  2003.81509   100.715551
# std       1.203878     3.656633     0.69967    40.187912
# min       1.000000     1.000000  2003.00000    33.000000
# 25%       2.000000     4.000000  2003.00000    68.000000
# ...

# %%
json_data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %% [markdown]
# # Perform data cleaning operations, such as handling missing values, removing duplicates, or correcting inconsistencies.

# %%
csv_data.isnull()
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  ORDERDATE  \
# ORDERNUMBER
# 10107                  False      False            False  False      False
# 10121                  False      False            False  False      False
# 10134                  False      False            False  False      False
# 10145                  False      False            False  False      False
# 10159                  False      False            False  False      False
# ...                      ...        ...              ...    ...        ...
# 10350                  False      False            False  False      False
# 10373                  False      False            False  False      False
# 10386                  False      False            False  False      False
# 10397                  False      False            False  False      False
# 10414                  False      False            False  False      False
#
# ...

# %%
csv_data.dropna(inplace= True)

# %%
csv_data
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERNUMBER
# 10223                     37     100.00                1  3965.66
# 10361                     20      72.55               13  1451.00
# 10270                     21     100.00                9  4905.39
# 10347                     30     100.00                1  3944.70
# 10391                     24     100.00                4  2416.56
# ...                      ...        ...              ...      ...
# 10120                     43      76.00               14  3268.00
# 10223                     26      67.20               15  1747.20
# 10361                     44     100.00               10  5001.92
# 10361                     35     100.00               11  4277.35
# 10361                     23      95.20               12  2189.60
#
#                    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# ORDERNUMBER
# 10223         2/20/2004 0:00  Shipped       1         2     2004
# ...

# %%
csv_data.drop_duplicates()
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERNUMBER
# 10223                     37     100.00                1  3965.66
# 10361                     20      72.55               13  1451.00
# 10270                     21     100.00                9  4905.39
# 10347                     30     100.00                1  3944.70
# 10391                     24     100.00                4  2416.56
# ...                      ...        ...              ...      ...
# 10120                     43      76.00               14  3268.00
# 10223                     26      67.20               15  1747.20
# 10361                     44     100.00               10  5001.92
# 10361                     35     100.00               11  4277.35
# 10361                     23      95.20               12  2189.60
#
#                    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# ORDERNUMBER
# 10223         2/20/2004 0:00  Shipped       1         2     2004
# ...

# %% [markdown]
# # Convert the data into a unified format, such as a common dataframe or data structure, to enable seamless analysis.

# %%
merged_data = pd.concat([csv_data , excel_data , json_data])

# %%
merged_data
# Out:
#        QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES        ORDERDATE  \
# 10223               37     100.00                1  3965.66   2/20/2004 0:00
# 10361               20      72.55               13  1451.00  12/17/2004 0:00
# 10270               21     100.00                9  4905.39   7/19/2004 0:00
# 10347               30     100.00                1  3944.70  11/29/2004 0:00
# 10391               24     100.00                4  2416.56    3/9/2005 0:00
# ...                ...        ...              ...      ...              ...
# 2818                20     100.00               15  2244.40   12/2/2004 0:00
# 2819                29     100.00                1  3978.51   1/31/2005 0:00
# 2820                43     100.00                4  5417.57    3/1/2005 0:00
# 2821                34      62.24                1  2116.16   3/28/2005 0:00
# 2822                47      65.52                9  3079.44    5/6/2005 0:00
#
# ...

# %% [markdown]
# # Perform data transformation tasks, such as merging multiple datasets, splitting columns, or deriving new variables

# %%
csv_data.groupby('STATUS').mean()
# Out:
# C:\Users\kgaur\AppData\Local\Temp\ipykernel_30336\3816291063.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   csv_data.groupby('STATUS').mean()
#             QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER        SALES  \
# STATUS
# In Process        40.923077  77.130769         7.000000  3382.417692
# Shipped           33.313433  84.818507         6.641791  3452.172313
#
#               QTR_ID  MONTH_ID      YEAR_ID        MSRP
# STATUS
# In Process  2.000000  5.000000  2005.000000   85.846154
# Shipped     2.738806  7.179104  2003.753731  102.067164

# %%
csv_data.groupby('STATUS').sum()
# Out:
# C:\Users\kgaur\AppData\Local\Temp\ipykernel_30336\1027966720.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   csv_data.groupby('STATUS').sum()
#             QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER      SALES  QTR_ID  \
# STATUS
# In Process              532    1002.70               91   43971.43      26
# Shipped                4464   11365.68              890  462591.09     367
#
#             MONTH_ID  YEAR_ID   MSRP
# STATUS
# In Process        65    26065   1116
# Shipped          962   268503  13677

# %% [markdown]
# # Analyze the sales data by performing descriptive statistics, aggregating data by specific variables, or calculating metrics such as total sales, average order value, or product category distribution.

# %%
merged_data['SALES'].sum()
# Out:
# 20571820.22

# %%
merged_data['ORDERLINENUMBER'].mean()
# Out:
# 6.471431037459002

# %% [markdown]
# # Create visualizations, such as bar plots, pie charts, or box plots, to represent the sales data and gain insights into sales trends, customer behavior, or product performance.

# %%
import seaborn as sns

# %%
sns.barplot(csv_data)
# Out:
# <Axes: >

# %%
sns.boxplot(csv_data)
# Out:
# <Axes: >
