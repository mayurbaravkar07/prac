# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 1 : Import the "RealEstate_Prices.csv" dataset. Clean column names by removing spaces,special characters, or renaming them for clarity.

# %%
df = pd.read_csv("Mumbai_Property.csv")

# %%
df
# Out:
#                      Property_Name  \
# 0                Omkar Alta Monte
# 1     T Bhimjyani Neelkanth Woods
# 2          Legend 1 Pramila Nagar
# 3                 Unnamed Property
# 4                 Unnamed Property
# ...                            ...
# 2575           Shagun White Woods
# 2576                   Guru Anant
# 2577        Balaji Mayuresh Delta
# 2578        Balaji Mayuresh Delta
# 2579      Gurukrupa Tulsi Heights
#
#                                                Location            Region  \
# 0                         W E Highway Malad East Mumbai      Malad Mumbai
# 1                                  Manpada Thane Mumbai     Manpada Thane
# 2                                   Dahisar West Mumbai    Dahisar Mumbai
# 3     Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
# ...                                                 ...               ...
# ...

# %%
# Clean and rename the columns
data = df.rename(columns={
    "Property_Name": "PropertyName",
    "Property_Age": "PropertyAge"
    # Add more columns as needed
})

# %%
data.head()
# Out:
#                    PropertyName  \
# 0             Omkar Alta Monte
# 1  T Bhimjyani Neelkanth Woods
# 2       Legend 1 Pramila Nagar
# 3              Unnamed Property
# 4              Unnamed Property
#
#                                             Location            Region  \
# 0                      W E Highway Malad East Mumbai      Malad Mumbai
# 1                               Manpada Thane Mumbai     Manpada Thane
# 2                                Dahisar West Mumbai    Dahisar Mumbai
# 3  Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
#
#     PropertyAge   Availability            Area_Tpye  Area_SqFt  Rate_SqFt  \
# 0   0 to 1 Year  Ready To Move  Super Built Up Area     2900.0      17241
# 1   1 to 5 Year  Ready To Move  Super Built Up Area     1900.0      12631
# 2      10+ Year  Ready To Move  Super Built Up Area      595.0      15966
# ...

# %% [markdown]
# ### Task 2 : Handle missing values in the dataset, deciding on an appropriate strategy (e.g., imputation or removal).

# %%
df.isna().sum()
# Out:
# Property_Name    0
# Location         0
# Region           0
# Property_Age     0
# Availability     0
# Area_Tpye        0
# Area_SqFt        0
# Rate_SqFt        0
# Floor_No         0
# Bedroom          0
# Bathroom         0
# Price_Lakh       0
# dtype: int64

# %% [markdown]
# #### Handling missing values by removing the rows and columns of the dataset

# %%
df.dropna(axis = 0 , inplace = True)

# %%
df.dropna(axis = 1 , inplace = True)

# %%
df
# Out:
#                      Property_Name  \
# 0                Omkar Alta Monte
# 1     T Bhimjyani Neelkanth Woods
# 2          Legend 1 Pramila Nagar
# 3                 Unnamed Property
# 4                 Unnamed Property
# ...                            ...
# 2575           Shagun White Woods
# 2576                   Guru Anant
# 2577        Balaji Mayuresh Delta
# 2578        Balaji Mayuresh Delta
# 2579      Gurukrupa Tulsi Heights
#
#                                                Location            Region  \
# 0                         W E Highway Malad East Mumbai      Malad Mumbai
# 1                                  Manpada Thane Mumbai     Manpada Thane
# 2                                   Dahisar West Mumbai    Dahisar Mumbai
# 3     Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
# ...                                                 ...               ...
# ...

# %% [markdown]
# ### Task 4 : Filter and subset the data based on specific criteria, such as a particular time period, property type, or location.

# %%
# Filtering data based on Area_SqFt column

new_data = df[df['Area_SqFt'] >= 2000]

# %%
new_data
# Out:
#                Property_Name  \
# 0          Omkar Alta Monte
# 24         Gauri Excellency
# 39      Swan Lake Apartment
# 58          Unnamed Property
# 83          Unnamed Property
# ...                      ...
# 2368    Paradise Sai Mannat
# 2464        Unnamed Property
# 2469        Unnamed Property
# 2484  Luxora Crystal Spires
# 2570      V R Radha Regency
#
#                                                Location                Region  \
# 0                         W E Highway Malad East Mumbai          Malad Mumbai
# 24                             2105 2106 Charkop Mumbai        Charkop Mumbai
# 39             1 101 Khar West Mumbai South West Mumbai          South Mumbai
# 58                                  Dahisar East Mumbai        Dahisar Mumbai
# 83                                Kandivali West Mumbai      Kandivali Mumbai
# ...                                                 ...                   ...
# ...

# %% [markdown]
# #### Filtering data based on the Floor_No available in the dataset

# %%
df['Floor_No'].unique()
# Out:
# array([14,  8,  3,  1,  5,  7,  4,  2, 26, 11, 21, 13,  0, 15, 16, 20,  9,
#        12, 10, -1,  6, 17, 23, 18, 19, 27, 34, 24, 28, 22, 36, 33, 25, 43,
#        47, 35, 42, 37, 29, 30, 31, 32, 41, 48, 45, 39, 59, 40, 46, 44, 38,
#        55, 49], dtype=int64)

# %%
min_flowers = 10
max_flowers = 40

filterd_data = df[(df['Floor_No'] >= min_flowers) & (df['Floor_No'] <= max_flowers)]

# %%
filterd_data
# Out:
#                  Property_Name  \
# 0            Omkar Alta Monte
# 19            Lodha Splendora
# 20      Lodha Palava Downtown
# 22            Unnamed Property
# 24           Gauri Excellency
# ...                        ...
# 2555      SK Imperial Heights
# 2568           Satyam Harmony
# 2569           Satyam Harmony
# 2571  Lodha Codename Bullseye
# 2576               Guru Anant
#
#                                              Location  \
# 0                       W E Highway Malad East Mumbai
# 19                       Ghodbunder Road Thane Mumbai
# 20                         Dombivli East Thane Mumbai
# 22           101 Bandra East Mumbai South West Mumbai
# 24                           2105 2106 Charkop Mumbai
# ...                                               ...
# 2555        103 Mira Road Mira Road And Beyond Mumbai
# 2568                 Koparkhairane Navi Mumbai Mumbai
# 2569                 Koparkhairane Navi Mumbai Mumbai
# ...

# %%
# Filtering data by availability df['Availability']
df['Availability'].unique()
# Out:
# array(['Ready To Move', 'Under Construction'], dtype=object)

# %%
want = 'Ready To Move'

filterr = df[df['Availability'] == want]

# %%
filterr
# Out:
#                      Property_Name  \
# 0                Omkar Alta Monte
# 1     T Bhimjyani Neelkanth Woods
# 2          Legend 1 Pramila Nagar
# 3                 Unnamed Property
# 4                 Unnamed Property
# ...                            ...
# 2575           Shagun White Woods
# 2576                   Guru Anant
# 2577        Balaji Mayuresh Delta
# 2578        Balaji Mayuresh Delta
# 2579      Gurukrupa Tulsi Heights
#
#                                                Location            Region  \
# 0                         W E Highway Malad East Mumbai      Malad Mumbai
# 1                                  Manpada Thane Mumbai     Manpada Thane
# 2                                   Dahisar West Mumbai    Dahisar Mumbai
# 3     Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
# ...                                                 ...               ...
# ...

# %% [markdown]
# ### Task 5 : Handle categorical variables by encoding them appropriately (e.g., one-hot encoding or label encoding) for further analysis.

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['Availability', 'Area_Tpye']) 
one_hot_encoded_data
# Out:
#                      Property_Name  \
# 0                Omkar Alta Monte
# 1     T Bhimjyani Neelkanth Woods
# 2          Legend 1 Pramila Nagar
# 3                 Unnamed Property
# 4                 Unnamed Property
# ...                            ...
# 2575           Shagun White Woods
# 2576                   Guru Anant
# 2577        Balaji Mayuresh Delta
# 2578        Balaji Mayuresh Delta
# 2579      Gurukrupa Tulsi Heights
#
#                                                Location            Region  \
# 0                         W E Highway Malad East Mumbai      Malad Mumbai
# 1                                  Manpada Thane Mumbai     Manpada Thane
# 2                                   Dahisar West Mumbai    Dahisar Mumbai
# 3     Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
# ...                                                 ...               ...
# ...

# %% [markdown]
# ### Task 6 : Aggregate the data to calculate summary statistics or derived metrics such as average sale prices by neighborhood or property type.

# %%
average_prices_by_neighborhood = data.groupby('Location')['Price_Lakh'].mean()
average_prices_by_neighborhood
# Out:
# Location
# 000 4 Bunglows Mumbai                                  700.0000
# 000 Anand Nagar Thane Mumbai                            69.0000
# 000 Andheri West Mumbai                                450.0000
# 000 Balkum Thane Mumbai                                210.0000
# 000 Borivali West Mumbai                               102.0000
#                                                          ...
# kavesar Thane Mumbai                                   120.3750
# kurla west Central Mumbai suburbs Mumbai               156.6000
# secter 7 koparkhairne Navi Mumbai Mumbai               110.0000
# thakurli Mumbai Beyond Thane Mumbai                     61.5125
# y K nagar Nx virar west Mira Road And Beyond Mumbai     38.0000
# Name: Price_Lakh, Length: 1308, dtype: float64

# %%
average_prices_by_property_type = data.groupby('Region')['Price_Lakh'].mean()
average_prices_by_property_type
# Out:
# Region
# Adaigaon Navi-Mumbai      26.500000
# Adharwadi Mumbai          63.680000
# Airoli Navi-Mumbai        87.625000
# Ambernath Mumbai          36.857143
# Ambika Nagar Mumbai       42.000000
#                            ...
# Village Navi-Mumbai       99.500000
# Wada Mumbai               55.000000
# Walkeshwar Mumbai       1062.500000
# Wayle Nagar               47.000000
# Yagna Nagar              221.333333
# Name: Price_Lakh, Length: 145, dtype: float64

# %%
aggregations = {
    'Price_Lakh': ['mean', 'median', 'max', 'min']
}
summary_statistics = data.groupby('Location').agg(aggregations)

# %%
summary_statistics
# Out:
#                                                    Price_Lakh                 \
#                                                          mean  median    max
# Location
# 000 4 Bunglows Mumbai                                700.0000  700.00  700.0
# 000 Anand Nagar Thane Mumbai                          69.0000   69.00   92.0
# 000 Andheri West Mumbai                              450.0000  450.00  450.0
# 000 Balkum Thane Mumbai                              210.0000  210.00  210.0
# 000 Borivali West Mumbai                             102.0000  102.00  102.0
# ...                                                       ...     ...    ...
# kavesar Thane Mumbai                                 120.3750   86.50  380.0
# kurla west Central Mumbai suburbs Mumbai             156.6000  110.00  250.0
# secter 7 koparkhairne Navi Mumbai Mumbai             110.0000  110.00  110.0
# thakurli Mumbai Beyond Thane Mumbai                   61.5125   57.55   79.0
# ...

# %% [markdown]
# ### Task 7 : Identify and handle outliers or extreme values in the data that may affect the analysis or modeling process.

# %%
Q1 = df['Price_Lakh'].quantile(0.25)
Q3 = df['Price_Lakh'].quantile(0.75)
IQR =  Q3 - Q1 


lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR


outliers = df[(df['Price_Lakh'] < lower_bound) & (df['Price_Lakh'] > upper_bound)]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [Property_Name, Location, Region, Property_Age, Availability, Area_Tpye, Area_SqFt, Rate_SqFt, Floor_No, Bedroom, Bathroom, Price_Lakh]
# Index: []

# %%
#### If we want to remove outliers we can use the following approach 

filterd_data = df[(df['Price_Lakh'] >= lower_bound) & (df['Price_Lakh'] <= upper_bound)]

# %%
filterd_data
# Out:
#                      Property_Name  \
# 1     T Bhimjyani Neelkanth Woods
# 2          Legend 1 Pramila Nagar
# 3                 Unnamed Property
# 4                 Unnamed Property
# 5                    Varun Garden
# ...                            ...
# 2575           Shagun White Woods
# 2576                   Guru Anant
# 2577        Balaji Mayuresh Delta
# 2578        Balaji Mayuresh Delta
# 2579      Gurukrupa Tulsi Heights
#
#                                                Location            Region  \
# 1                                  Manpada Thane Mumbai     Manpada Thane
# 2                                   Dahisar West Mumbai    Dahisar Mumbai
# 3     Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
# 5                                  Manpada Thane Mumbai     Manpada Thane
# ...                                                 ...               ...
# ...
